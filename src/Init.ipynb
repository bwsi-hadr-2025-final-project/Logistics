# %% [markdown]
# ## Initialization Notebook
# This is your initialization notebook.
#
# **What's this for?**
#
# You can put custom code you want us to run every time we setup your environment in here.
#
# **Awesome! Anything I should not put in here?**
#
# Please don't install `jupyter` or `jedi` packages, they would break your Deepnote environment. Also, no need to put `!pip install`s here, we already save those automatically!
#
# **I want to learn more!**
#
# Great! Just [head over to our docs](https://deepnote.com/docs/custom-initialization).

# %%
# %%bash
# # If your project has a 'requirements.txt' file, we'll install it here.
# if test -f requirements.txt
#   then
#     pip install -r ./requirements.txt
#   else echo "There's no requirements.txt, so nothing to install."
# fi
# Out:
# Collecting contextily
#   Downloading contextily-1.6.2-py3-none-any.whl (17 kB)
# Requirement already satisfied: folium>=0.12 in /root/venv/lib/python3.10/site-packages (from -r ./requirements.txt (line 2)) (0.20.0)
# Collecting osmnx
#   Downloading osmnx-2.0.5-py3-none-any.whl (101 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━���━━━━━━━━━ 101.3/101.3 kB 15.1 MB/s eta 0:00:00
# Collecting networkx
#   Downloading networkx-3.4.2-py3-none-any.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━���━━━━━━━━━━━ 1.7/1.7 MB 97.3 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /root/venv/lib/python3.10/site-packages (from -r ./requirements.txt (line 5)) (2.1.4)
# Requirement already satisfied: geopandas in /root/venv/lib/python3.10/site-packages (from -r ./requirements.txt (line 6)) (1.1.1)
# Collecting mapclassify
#   Downloading mapclassify-2.8.1-py3-none-any.whl (59 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━���━━━━━━━━━━━ 59.1/59.1 kB 11.4 MB/s eta 0:00:00
# Collecting ee
#   Downloading ee-0.2.tar.gz (3.0 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting geemap
#   Downloading geemap-0.36.0-py3-none-any.whl (631 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━���━━━━━━━━━ 631.3/631.3 kB 66.7 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /root/venv/lib/python3.10/site-packages (from -r ./requirements.txt (line 10)) (1.25.2)
# Requirement already satisfied: matplotlib in /root/venv/lib/python3.10/site-packages (from -r ./requirements.txt (line 11)) (3.6.3)
# Requirement already satisfied: shapely in /root/venv/lib/python3.10/site-packages (from -r ./requirements.txt (line 12)) (2.1.1)
# Requirement already satisfied: xyzservices in /root/venv/lib/python3.10/site-packages (from contextily->-r ./requirements.txt (line 1)) (2025.4.0)
# Requirement already satisfied: requests in /root/venv/lib/python3.10/site-packages (from contextily->-r ./requirements.txt (line 1)) (2.32.4)
# Requirement already satisfied: joblib in /root/venv/lib/python3.10/site-packages (from contextily->-r ./requirements.txt (line 1)) (1.5.1)
# Requirement already satisfied: pillow in /root/venv/lib/python3.10/site-packages (from contextily->-r ./requirements.txt (line 1)) (11.3.0)
# Collecting mercantile
#   Downloading mercantile-1.2.1-py3-none-any.whl (14 kB)
# Collecting geopy
#   Downloading geopy-2.4.1-py3-none-any.whl (125 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━���━━━━━━━━━ 125.4/125.4 kB 20.8 MB/s eta 0:00:00
# Collecting rasterio
#   Downloading rasterio-1.4.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (22.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━���━━━━━━━━━━━ 22.2/22.2 MB 97.2 MB/s eta 0:00:00
# Requirement already satisfied: jinja2>=2.9 in /root/venv/lib/python3.10/site-packages (from folium>=0.12->-r ./requirements.txt (line 2)) (3.1.6)
# Requirement already satisfied: branca>=0.6.0 in /root/venv/lib/python3.10/site-packages (from folium>=0.12->-r ./requirements.txt (line 2)) (0.8.1)
# Requirement already satisfied: pytz>=2020.1 in /root/venv/lib/python3.10/site-packages (from pandas->-r ./requirements.txt (line 5)) (2025.2)
# Requirement already satisfied: tzdata>=2022.1 in /root/venv/lib/python3.10/site-packages (from pandas->-r ./requirements.txt (line 5)) (2025.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /root/venv/lib/python3.10/site-packages (from pandas->-r ./requirements.txt (line 5)) (2.9.0.post0)
# Requirement already satisfied: pyproj>=3.5.0 in /root/venv/lib/python3.10/site-packages (from geopandas->-r ./requirements.txt (line 6)) (3.7.1)
# Requirement already satisfied: pyogrio>=0.7.2 in /root/venv/lib/python3.10/site-packages (from geopandas->-r ./requirements.txt (line 6)) (0.11.0)
# Requirement already satisfied: packaging in /root/venv/lib/python3.10/site-packages (from geopandas->-r ./requirements.txt (line 6)) (25.0)
# Requirement already satisfied: scikit-learn>=1.0 in /root/venv/lib/python3.10/site-packages (from mapclassify->-r ./requirements.txt (line 7)) (1.1.3)
# Requirement already satisfied: scipy>=1.8 in /root/venv/lib/python3.10/site-packages (from mapclassify->-r ./requirements.txt (line 7)) (1.9.3)
# Collecting blessings
#   Downloading blessings-1.7-py3-none-any.whl (18 kB)
# Collecting eerepr>=0.1.0
#   Downloading eerepr-0.1.2-py3-none-any.whl (9.5 kB)
# Collecting pyshp>=2.3.1
#   Downloading pyshp-2.3.1-py2.py3-none-any.whl (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━���━━━━━━━━━━━ 46.5/46.5 kB 20.5 MB/s eta 0:00:00
# Collecting ipyleaflet>=0.19.2
#   Downloading ipyleaflet-0.20.0-py3-none-any.whl (31 kB)
# Collecting bqplot
#   Downloading bqplot-0.12.45-py2.py3-none-any.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━���━━━━━━━━━━━ 1.2/1.2 MB 128.6 MB/s eta 0:00:00
# Collecting earthengine-api>=1.0.0
#   Downloading earthengine_api-1.6.1-py3-none-any.whl (463 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━���━━━━━━━━━ 463.2/463.2 kB 97.3 MB/s eta 0:00:00
# Collecting anywidget
#   Downloading anywidget-0.9.18-py3-none-any.whl (220 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━���━━━━━━━━━ 220.7/220.7 kB 68.0 MB/s eta 0:00:00
# Requirement already satisfied: plotly in /root/venv/lib/python3.10/site-packages (from geemap->-r ./requirements.txt (line 9)) (6.2.0)
# Collecting python-box
#   Downloading python_box-7.3.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━���━━━━━━━━━━━ 4.0/4.0 MB 165.8 MB/s eta 0:00:00
# Collecting pyperclip
#   Downloading pyperclip-1.9.0.tar.gz (20 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting ipytree
#   Downloading ipytree-0.2.2-py2.py3-none-any.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━���━━━━━━━━━━━ 1.3/1.3 MB 146.7 MB/s eta 0:00:00
# Collecting geocoder
#   Downloading geocoder-1.38.1-py2.py3-none-any.whl (98 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━���━━━━━━━━━━━ 98.6/98.6 kB 39.0 MB/s eta 0:00:00
# Collecting colour
#   Downloading colour-0.1.5-py2.py3-none-any.whl (23 kB)
# Collecting scooby
#   Downloading scooby-0.10.1-py3-none-any.whl (18 kB)
# Collecting ipyevents
#   Downloading ipyevents-2.0.2-py3-none-any.whl (101 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━���━━━━━━━━━ 101.8/101.8 kB 41.3 MB/s eta 0:00:00
# Collecting ipyfilechooser>=0.6.0
#   Downloading ipyfilechooser-0.6.0-py3-none-any.whl (11 kB)
# Requirement already satisfied: fonttools>=4.22.0 in /root/venv/lib/python3.10/site-packages (from matplotlib->-r ./requirements.txt (line 11)) (4.59.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /root/venv/lib/python3.10/site-packages (from matplotlib->-r ./requirements.txt (line 11)) (1.4.8)
# Requirement already satisfied: contourpy>=1.0.1 in /root/venv/lib/python3.10/site-packages (from matplotlib->-r ./requirements.txt (line 11)) (1.3.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /root/venv/lib/python3.10/site-packages (from matplotlib->-r ./requirements.txt (line 11)) (3.2.3)
# Requirement already satisfied: cycler>=0.10 in /root/venv/lib/python3.10/site-packages (from matplotlib->-r ./requirements.txt (line 11)) (0.12.1)
# Collecting google-auth-httplib2>=0.0.3
#   Downloading google_auth_httplib2-0.2.0-py2.py3-none-any.whl (9.3 kB)
# Collecting google-cloud-storage
#   Downloading google_cloud_storage-3.2.0-py3-none-any.whl (176 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━���━━━━━━━━━ 176.1/176.1 kB 49.8 MB/s eta 0:00:00
# Collecting google-api-python-client>=1.12.1
#   Downloading google_api_python_client-2.177.0-py3-none-any.whl (13.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━���━━━━━━━━━━ 13.7/13.7 MB 154.7 MB/s eta 0:00:00
# Requirement already satisfied: google-auth>=1.4.1 in /root/venv/lib/python3.10/site-packages (from earthengine-api>=1.0.0->geemap->-r ./requirements.txt (line 9)) (2.40.3)
# Collecting httplib2<1dev,>=0.9.2
#   Downloading httplib2-0.22.0-py3-none-any.whl (96 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━���━━━━━━━━━━━ 96.9/96.9 kB 42.3 MB/s eta 0:00:00
# Collecting ipywidgets
#   Downloading ipywidgets-8.1.7-py3-none-any.whl (139 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━���━━━━━━━━━ 139.8/139.8 kB 44.4 MB/s eta 0:00:00
# Collecting jupyter-leaflet<0.21,>=0.20
#   Downloading jupyter_leaflet-0.20.0-py3-none-any.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━���━━━━━━━━━━━ 1.1/1.1 MB 137.4 MB/s eta 0:00:00
# Collecting traittypes<3,>=0.2.1
#   Downloading traittypes-0.2.1-py2.py3-none-any.whl (8.6 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /root/venv/lib/python3.10/site-packages (from jinja2>=2.9->folium>=0.12->-r ./requirements.txt (line 2)) (3.0.2)
# Requirement already satisfied: certifi in /root/venv/lib/python3.10/site-packages (from pyogrio>=0.7.2->geopandas->-r ./requirements.txt (line 6)) (2025.7.14)
# Requirement already satisfied: six>=1.5 in /root/venv/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas->-r ./requirements.txt (line 5)) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /root/venv/lib/python3.10/site-packages (from requests->contextily->-r ./requirements.txt (line 1)) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /root/venv/lib/python3.10/site-packages (from requests->contextily->-r ./requirements.txt (line 1)) (2.5.0)
# Requirement already satisfied: idna<4,>=2.5 in /root/venv/lib/python3.10/site-packages (from requests->contextily->-r ./requirements.txt (line 1)) (3.10)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /root/venv/lib/python3.10/site-packages (from scikit-learn>=1.0->mapclassify->-r ./requirements.txt (line 7)) (3.6.0)
# Collecting psygnal>=0.8.1
#   Downloading psygnal-0.14.0-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (847 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━���━━━━━━━━ 848.0/848.0 kB 130.5 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=4.2.0 in /root/venv/lib/python3.10/site-packages (from anywidget->geemap->-r ./requirements.txt (line 9)) (4.14.1)
# Requirement already satisfied: traitlets>=4.3.0 in /root/venv/lib/python3.10/site-packages (from bqplot->geemap->-r ./requirements.txt (line 9)) (5.14.3)
# Requirement already satisfied: future in /root/venv/lib/python3.10/site-packages (from geocoder->geemap->-r ./requirements.txt (line 9)) (1.0.0)
# Requirement already satisfied: click in /root/venv/lib/python3.10/site-packages (from geocoder->geemap->-r ./requirements.txt (line 9)) (8.2.1)
# Collecting ratelim
#   Downloading ratelim-0.1.6-py2.py3-none-any.whl (4.0 kB)
# Collecting geographiclib<3,>=1.52
#   Downloading geographiclib-2.0-py3-none-any.whl (40 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━���━━━━━━━━━━━ 40.3/40.3 kB 16.2 MB/s eta 0:00:00
# Requirement already satisfied: narwhals>=1.15.1 in /root/venv/lib/python3.10/site-packages (from plotly->geemap->-r ./requirements.txt (line 9)) (1.47.1)
# Collecting cligj>=0.5
#   Downloading cligj-0.7.2-py3-none-any.whl (7.1 kB)
# Collecting affine
#   Downloading affine-2.4.0-py3-none-any.whl (15 kB)
# Collecting click-plugins
#   Downloading click_plugins-1.1.1.2-py2.py3-none-any.whl (11 kB)
# Requirement already satisfied: attrs in /root/venv/lib/python3.10/site-packages (from rasterio->contextily->-r ./requirements.txt (line 1)) (25.3.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5 in /toolkit-cache/0.2.28/python3.10/kernel-libs/lib/python3.10/site-packages (from google-api-python-client>=1.12.1->earthengine-api>=1.0.0->geemap->-r ./requirements.txt (line 9)) (2.19.2)
# Collecting uritemplate<5,>=3.0.1
#   Downloading uritemplate-4.2.0-py3-none-any.whl (11 kB)
# Requirement already satisfied: rsa<5,>=3.1.4 in /root/venv/lib/python3.10/site-packages (from google-auth>=1.4.1->earthengine-api>=1.0.0->geemap->-r ./requirements.txt (line 9)) (4.9.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /root/venv/lib/python3.10/site-packages (from google-auth>=1.4.1->earthengine-api>=1.0.0->geemap->-r ./requirements.txt (line 9)) (0.4.2)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /root/venv/lib/python3.10/site-packages (from google-auth>=1.4.1->earthengine-api>=1.0.0->geemap->-r ./requirements.txt (line 9)) (5.5.2)
# Collecting jupyterlab_widgets~=3.0.15
#   Downloading jupyterlab_widgets-3.0.15-py3-none-any.whl (216 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━���━━━━━━━━━ 216.6/216.6 kB 51.6 MB/s eta 0:00:00
# Collecting widgetsnbextension~=4.0.14
#   Downloading widgetsnbextension-4.0.14-py3-none-any.whl (2.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━���━━━━━━━━━━━ 2.2/2.2 MB 152.1 MB/s eta 0:00:00
# Requirement already satisfied: ipython>=6.1.0 in /root/venv/lib/python3.10/site-packages (from ipywidgets->ipyfilechooser>=0.6.0->geemap->-r ./requirements.txt (line 9)) (8.37.0)
# Requirement already satisfied: comm>=0.1.3 in /toolkit-cache/0.2.28/python3.10/kernel-libs/lib/python3.10/site-packages (from ipywidgets->ipyfilechooser>=0.6.0->geemap->-r ./requirements.txt (line 9)) (0.2.2)
# Requirement already satisfied: google-resumable-media<3.0.0,>=2.7.2 in /toolkit-cache/0.2.28/python3.10/kernel-libs/lib/python3.10/site-packages (from google-cloud-storage->earthengine-api>=1.0.0->geemap->-r ./requirements.txt (line 9)) (2.7.2)
# Requirement already satisfied: google-crc32c<2.0.0,>=1.1.3 in /toolkit-cache/0.2.28/python3.10/kernel-libs/lib/python3.10/site-packages (from google-cloud-storage->earthengine-api>=1.0.0->geemap->-r ./requirements.txt (line 9)) (1.5.0)
# Collecting google-cloud-core<3.0.0,>=2.4.2
#   Downloading google_cloud_core-2.4.3-py2.py3-none-any.whl (29 kB)
# Requirement already satisfied: decorator in /root/venv/lib/python3.10/site-packages (from ratelim->geocoder->geemap->-r ./requirements.txt (line 9)) (5.2.1)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in /toolkit-cache/0.2.28/python3.10/kernel-libs/lib/python3.10/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client>=1.12.1->earthengine-api>=1.0.0->geemap->-r ./requirements.txt (line 9)) (1.24.0)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /toolkit-cache/0.2.28/python3.10/kernel-libs/lib/python3.10/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client>=1.12.1->earthengine-api>=1.0.0->geemap->-r ./requirements.txt (line 9)) (1.65.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0.dev0,>=3.19.5 in /root/venv/lib/python3.10/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client>=1.12.1->earthengine-api>=1.0.0->geemap->-r ./requirements.txt (line 9)) (4.25.8)
# Requirement already satisfied: exceptiongroup in /root/venv/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap->-r ./requirements.txt (line 9)) (1.3.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /root/venv/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap->-r ./requirements.txt (line 9)) (3.0.51)
# Requirement already satisfied: jedi>=0.16 in /root/venv/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap->-r ./requirements.txt (line 9)) (0.19.2)
# Requirement already satisfied: stack_data in /root/venv/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap->-r ./requirements.txt (line 9)) (0.6.3)
# Requirement already satisfied: pygments>=2.4.0 in /root/venv/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap->-r ./requirements.txt (line 9)) (2.19.2)
# Requirement already satisfied: matplotlib-inline in /root/venv/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap->-r ./requirements.txt (line 9)) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /root/venv/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap->-r ./requirements.txt (line 9)) (4.9.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /root/venv/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.4.1->earthengine-api>=1.0.0->geemap->-r ./requirements.txt (line 9)) (0.6.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /root/venv/lib/python3.10/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap->-r ./requirements.txt (line 9)) (0.8.4)
# Requirement already satisfied: ptyprocess>=0.5 in /root/venv/lib/python3.10/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap->-r ./requirements.txt (line 9)) (0.7.0)
# Requirement already satisfied: wcwidth in /root/venv/lib/python3.10/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap->-r ./requirements.txt (line 9)) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in /root/venv/lib/python3.10/site-packages (from stack_data->ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap->-r ./requirements.txt (line 9)) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /root/venv/lib/python3.10/site-packages (from stack_data->ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap->-r ./requirements.txt (line 9)) (3.0.0)
# Requirement already satisfied: pure-eval in /root/venv/lib/python3.10/site-packages (from stack_data->ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap->-r ./requirements.txt (line 9)) (0.2.3)
# Building wheels for collected packages: ee, pyperclip
#   Building wheel for ee (setup.py): started
#   Building wheel for ee (setup.py): finished with status 'done'
#   Created wheel for ee: filename=ee-0.2-py3-none-any.whl size=3655 sha256=1e19533edab4dd7fd8a86aa9af0788da7af974b3d67c534bcbcf6adac74b273e
#   Stored in directory: /root/.cache/pip/wheels/cb/b1/a5/d16d395d190f232181add4c4af67a74c2de272875759921aef
#   Building wheel for pyperclip (setup.py): started
#   Building wheel for pyperclip (setup.py): finished with status 'done'
#   Created wheel for pyperclip: filename=pyperclip-1.9.0-py3-none-any.whl size=11001 sha256=fcf829dd1cef6f62ce8b1d3560cc6fe46cac9756a69791bf8829db51855098e7
#   Stored in directory: /root/.cache/pip/wheels/cc/ae/36/ee17d1de094fcb61e24106cb329b5103861e819f94bef5e10a
# Successfully built ee pyperclip
# Installing collected packages: pyperclip, colour, widgetsnbextension, uritemplate, traittypes, scooby, ratelim, python-box, pyshp, psygnal, networkx, mercantile, jupyterlab_widgets, jupyter-leaflet, httplib2, geographiclib, cligj, click-plugins, blessings, affine, rasterio, geopy, geocoder, ee, mapclassify, ipywidgets, google-auth-httplib2, contextily, osmnx, ipytree, ipyleaflet, ipyfilechooser, ipyevents, google-cloud-core, google-api-python-client, bqplot, anywidget, google-cloud-storage, earthengine-api, eerepr, geemap
#   Attempting uninstall: google-cloud-core
#     Found existing installation: google-cloud-core 2.4.1
#     Not uninstalling google-cloud-core at /toolkit-cache/0.2.28/python3.10/kernel-libs/lib/python3.10/site-packages, outside environment /root/venv
#     Can't uninstall 'google-cloud-core'. No files were found to uninstall.
# Successfully installed affine-2.4.0 anywidget-0.9.18 blessings-1.7 bqplot-0.12.45 click-plugins-1.1.1.2 cligj-0.7.2 colour-0.1.5 contextily-1.6.2 earthengine-api-1.6.1 ee-0.2 eerepr-0.1.2 geemap-0.36.0 geocoder-1.38.1 geographiclib-2.0 geopy-2.4.1 google-api-python-client-2.177.0 google-auth-httplib2-0.2.0 google-cloud-core-2.4.3 google-cloud-storage-3.2.0 httplib2-0.22.0 ipyevents-2.0.2 ipyfilechooser-0.6.0 ipyleaflet-0.20.0 ipytree-0.2.2 ipywidgets-8.1.7 jupyter-leaflet-0.20.0 jupyterlab_widgets-3.0.15 mapclassify-2.8.1 mercantile-1.2.1 networkx-3.4.2 osmnx-2.0.5 psygnal-0.14.0 pyperclip-1.9.0 pyshp-2.3.1 python-box-7.3.2 rasterio-1.4.3 ratelim-0.1.6 scooby-0.10.1 traittypes-0.2.1 uritemplate-4.2.0 widgetsnbextension-4.0.14
#
# [notice] A new release of pip is available: 23.0.1 -> 25.2
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=2dcc0f2a-2908-4fb2-84a7-f396276d2cf8' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
